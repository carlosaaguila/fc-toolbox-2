# %%
#establishing environment
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import scipy
from scipy.stats import pearsonr
from scipy import signal as sig
from scipy.io import loadmat, savemat

# %% [markdown]
# split_1 = loadmat('/Users/carlosaguila/PycharmProjects/CNT_Interictal_Spikes/Results_v1/split_1.mat'); #local machine save #this is 10 gdfs
# fs=512;

# %%
def ch_mean(ch, seq_idx):
    val = split_1['values_all'][0][seq_idx][:,ch] 
    return np.mean(val)

def mean_max(sequence_split, values, seq_idx):
    seq_0_concat = np.concatenate(sequence_split)
    seq_0_concat = np.concatenate(seq_0_concat) #double concatenate so that everything is in a array corresponding - basically turns into GDF
    ch_uniq = np.unique(seq_0_concat[:,0]) #finds the unique channels in each run_time
    #finds the mean of the max of each channel's spike index.
    meanmax_per_ch = [];
    all_max = []
    for ch in ch_uniq:
        x = np.where(seq_0_concat[:,0] == ch)[0] #index where all spikes are per channel per run_time
        max_in_ch = []
        chs = []
        for i in x:
            val = values[seq_0_concat[i,1]-20:seq_0_concat[i,1]+20, ch] - ch_mean(ch, seq_idx) #finding value at the spike and channel from x
            val_max = np.max(np.abs(val))
            max_in_ch.append(val_max)
            chs.append(np.unique(ch))
        meanmax_per_ch.append(np.mean(max_in_ch))
        all_max.append([np.concatenate(chs),max_in_ch])
        
    chs2 = (np.concatenate(np.transpose(all_max)[0]))
    maxs2 = (np.concatenate(np.transpose(all_max)[1]))
    all_max_2 = [chs2,maxs2] #reshape of maxs in all channels.
    return meanmax_per_ch, ch_uniq, all_max_2

def ALL_mean_max(split_1): #input would be the complete matrix assuming 'values_all' and 'seqs_all' are the base names
    mean_max_ALL = []
    ch_uniq_ALL = []
    max_I_ALL = []
    
    for I in range(len(split_1['values_all'][0])):
        values_gdf_I = split_1['values_all'][0,I]
        seq_I = split_1['seqs_all'][0,I]
        mean_max_seq_I, ch_uniq_I, all_max_I = mean_max(seq_I,values_gdf_I,I)
        mean_max_ALL.append(mean_max_seq_I)
        ch_uniq_ALL.append(ch_uniq_I)
        max_I_ALL.append(all_max_I)
    
    ch_uniq_AL_C = np.concatenate(ch_uniq_ALL)
    mean_max_ALL_C = np.concatenate(mean_max_ALL)
    ALL_CH = []
    ALL_maxvalues = []
    for s in range(len(max_I_ALL)):
        ALL_CH.append((max_I_ALL[s][0]))
        ALL_maxvalues.append((max_I_ALL[s][1]))
    ALL_CH = np.concatenate(ALL_CH)
    ALL_maxvalues = np.concatenate(ALL_maxvalues)
    max_I_ALL = [ALL_CH,ALL_maxvalues]
    ALL_mean_max_with_ch = [ch_uniq_AL_C,mean_max_ALL_C]
    return ALL_mean_max_with_ch, max_I_ALL

#creates a compilation of every channel in all gdfs and there respective means of max absolute peak values 
def meanofmeanmax_per_ch(split_1): #input is the complete split file.
    all_mean_max, max_I_all = ALL_mean_max(split_1) #uses ALL_mean_max function to get you a complete list of concatenated mean max's

    #code to get means of means per channel.
    all_mean_max = np.transpose(all_mean_max)
    max_I_all = np.transpose(max_I_all)
    popmean= np.nanmean(max_I_all[:,1])
    popstd = np.nanstd(max_I_all[:,1])
    ch_uniq = np.unique(all_mean_max[:,0]) #finds the unique channels in concatenated list
    ch_uniq_ALL = np.unique(max_I_all[:,0])
    
    means = []
    means_from_all_maxes = []
    std_from_all_maxes = []
    for ch in ch_uniq:
        x = np.where(all_mean_max[:,0] == ch)[0]#index where all spikes are per channel per run_time
        means.append(np.mean(all_mean_max[x,1]))
    for ch2 in ch_uniq_ALL:
        x2 = np.where(max_I_all[:,0] == ch2)[0]
        means_from_all_maxes.append(np.mean(max_I_all[x2,1]))
        std_from_all_maxes.append(np.std(max_I_all[x2,1]))
    meanofmeanmax = [ch_uniq,means]    
    stats_per_ch = [ch_uniq_ALL, means_from_all_maxes, std_from_all_maxes]
    
    return np.transpose(meanofmeanmax), np.transpose(stats_per_ch), popmean, popstd # ['channel','mean of mean max'] ['channel', 'mean of maxes for all channels', 'std of maxes for all channels']

#test for significance
from scipy import stats as st

#perform 1-sample t test
def stu_ttest_per_chn(split_1):
    _ , max_I_all = ALL_mean_max(split_1)
    _ , stats_ch_ALL, popmean, popstd = meanofmeanmax_per_ch(split_1)
    max_I_all = np.transpose(max_I_all)
    ch_uniq_ALL = np.unique(max_I_all[:,0])
    stats_per_chn = []
    for ch2 in ch_uniq_ALL:
        x2 = np.where(max_I_all[:,0] == ch2)[0]
        stats = st.ttest_1samp(a=max_I_all[x2,1], popmean=popmean,alternative='greater')
        stats_per_chn.append(stats)
    stats_per_chn_labeled = [ch_uniq_ALL, stats_per_chn];
    return np.transpose(stats_per_chn_labeled)

# %%
#zero centered max values student t test - sample 1
x = stu_ttest_per_chn(split_1)
print(x)
# Out:
# [[7.0
#   Ttest_1sampResult(statistic=7.0658781654575575, pvalue=5.8514798438806565e-09)]
#  [8.0
#   Ttest_1sampResult(statistic=3.1199813156007545, pvalue=0.0014506316928448696)]
#  [9.0
#   Ttest_1sampResult(statistic=2.770615465521966, pvalue=0.003994327811386186)]
#  [10.0
#   Ttest_1sampResult(statistic=5.583772004734263, pvalue=2.5084580974712e-06)]
#  [11.0
#   Ttest_1sampResult(statistic=0.8624687411028958, pvalue=0.1965530984067183)]
#  [12.0
#   Ttest_1sampResult(statistic=-2.684218391528946, pvalue=0.9946445560040057)]
#  [13.0
#   Ttest_1sampResult(statistic=-2.2711232477362144, pvalue=0.9796081800803143)]
#  [14.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [15.0
#   Ttest_1sampResult(statistic=-17.303177489422406, pvalue=0.9999999999984267)]
#  [16.0 Ttest_1sampResult(statistic=-20.700499035640817, pvalue=1.0)]
#  [17.0 Ttest_1sampResult(statistic=-29.82277441355374, pvalue=1.0)]
#  [18.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [20.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [22.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [26.0
#   Ttest_1sampResult(statistic=4.014351158774126, pvalue=0.02840845223350321)]
#  [27.0
#   Ttest_1sampResult(statistic=4.5218042010056, pvalue=0.0004347301045495897)]
#  [28.0
#   Ttest_1sampResult(statistic=2.538960919950329, pvalue=0.008479242601116807)]
#  [29.0 Ttest_1sampResult(statistic=-29.015633728973942, pvalue=1.0)]
#  [30.0
#   Ttest_1sampResult(statistic=-14.839887059575043, pvalue=0.9999999999999666)]
#  [31.0
#   Ttest_1sampResult(statistic=-13.635583114737758, pvalue=0.9999999999983537)]
#  [32.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [34.0
#   Ttest_1sampResult(statistic=-0.43267388080048313, pvalue=0.6666234666659163)]
#  [35.0
#   Ttest_1sampResult(statistic=-1.8916745419821206, pvalue=0.968603153010978)]
#  [36.0
#   Ttest_1sampResult(statistic=6.49635199261518, pvalue=5.544141441599094e-10)]
#  [37.0 Ttest_1sampResult(statistic=-12.466333985646457, pvalue=1.0)]
#  [38.0
#   Ttest_1sampResult(statistic=2.9783045677073288, pvalue=0.0017487730699457546)]
#  [39.0
#   Ttest_1sampResult(statistic=0.045192338737593124, pvalue=0.48200874595203563)]
#  [40.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [41.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [42.0 Ttest_1sampResult(statistic=-20.343358712554853, pvalue=1.0)]
#  [43.0 Ttest_1sampResult(statistic=-19.40997347280354, pvalue=1.0)]
#  [44.0 Ttest_1sampResult(statistic=-18.420698097982157, pvalue=1.0)]
#  [45.0
#   Ttest_1sampResult(statistic=7.63934400610613, pvalue=9.537581303523849e-12)]
#  [46.0
#   Ttest_1sampResult(statistic=14.05765401058885, pvalue=2.7456455787419096e-29)]
#  [47.0
#   Ttest_1sampResult(statistic=7.355138601563862, pvalue=9.967920485243661e-11)]
#  [48.0
#   Ttest_1sampResult(statistic=5.330697257089668, pvalue=1.218990747750188e-07)]
#  [49.0
#   Ttest_1sampResult(statistic=31.0732484691016, pvalue=4.433559256911858e-96)]
#  [50.0
#   Ttest_1sampResult(statistic=19.965766041350133, pvalue=3.048323362847052e-64)]
#  [51.0
#   Ttest_1sampResult(statistic=6.78607191357732, pvalue=1.5799207106495756e-11)]
#  [52.0 Ttest_1sampResult(statistic=-33.205898767960626, pvalue=1.0)]
#  [53.0
#   Ttest_1sampResult(statistic=-8.204362115209678, pvalue=0.9999999999999903)]
#  [54.0 Ttest_1sampResult(statistic=-21.667376378701515, pvalue=1.0)]
#  [55.0 Ttest_1sampResult(statistic=-17.106596416993252, pvalue=1.0)]
#  [56.0 Ttest_1sampResult(statistic=-14.936275287559685, pvalue=1.0)]
#  [57.0
#   Ttest_1sampResult(statistic=16.50361214016954, pvalue=1.1439387049397245e-35)]
#  [58.0
#   Ttest_1sampResult(statistic=2.362646464560346, pvalue=0.009591627289249387)]
#  [59.0
#   Ttest_1sampResult(statistic=-7.1522187465650795, pvalue=0.9999999999309293)]
#  [60.0
#   Ttest_1sampResult(statistic=-7.116651507208631, pvalue=0.9999999996413681)]
#  [61.0
#   Ttest_1sampResult(statistic=-7.3121883647718215, pvalue=0.9999999999363219)]
#  [62.0
#   Ttest_1sampResult(statistic=-9.21470727768844, pvalue=0.9999999999998804)]
#  [63.0
#   Ttest_1sampResult(statistic=-9.669719368377761, pvalue=0.9999999972258224)]
#  [65.0
#   Ttest_1sampResult(statistic=-0.14969146523735122, pvalue=0.5586637261827924)]
#  [66.0
#   Ttest_1sampResult(statistic=-4.502573204621769, pvalue=0.999993701522321)]
#  [67.0
#   Ttest_1sampResult(statistic=-4.897050136363208, pvalue=0.9999988483130489)]
#  [68.0 Ttest_1sampResult(statistic=-9.360414325605772, pvalue=1.0)]
#  [69.0 Ttest_1sampResult(statistic=-11.357249670493463, pvalue=1.0)]
#  [70.0
#   Ttest_1sampResult(statistic=-0.10240004295163985, pvalue=0.5406583961508145)]
#  [71.0
#   Ttest_1sampResult(statistic=-6.951031450799357, pvalue=0.9999999997098917)]
#  [72.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [73.0 Ttest_1sampResult(statistic=-56.43236637005477, pvalue=1.0)]
#  [74.0
#   Ttest_1sampResult(statistic=-10.853043273632126, pvalue=0.9999999832095827)]
#  [75.0
#   Ttest_1sampResult(statistic=2.952891153451874, pvalue=0.0028810666356970916)]
#  [76.0
#   Ttest_1sampResult(statistic=-0.3706725068124709, pvalue=0.6441632942244033)]
#  [77.0
#   Ttest_1sampResult(statistic=-0.31394635835594614, pvalue=0.6227240240775189)]
#  [78.0
#   Ttest_1sampResult(statistic=5.759319876835681, pvalue=8.759717628549266e-08)]
#  [79.0 Ttest_1sampResult(statistic=-31.896427738098154, pvalue=1.0)]
#  [80.0 Ttest_1sampResult(statistic=-21.697568706456465, pvalue=1.0)]
#  [81.0 Ttest_1sampResult(statistic=-128.1705861739267, pvalue=1.0)]
#  [83.0
#   Ttest_1sampResult(statistic=-27.78777181087718, pvalue=0.9999488484861977)]
#  [84.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [85.0
#   Ttest_1sampResult(statistic=4.76822803104971, pvalue=0.0001835984487558106)]
#  [86.0
#   Ttest_1sampResult(statistic=2.801777042427376, pvalue=0.003431769280347143)]
#  [87.0
#   Ttest_1sampResult(statistic=7.144078874772268, pvalue=1.3746799669762975e-10)]
#  [88.0
#   Ttest_1sampResult(statistic=-3.9174891118857387, pvalue=0.9999366527816475)]
#  [89.0 Ttest_1sampResult(statistic=-20.002092450412153, pvalue=1.0)]
#  [90.0
#   Ttest_1sampResult(statistic=7.156764560648318, pvalue=1.709545657117742e-11)]
#  [91.0 Ttest_1sampResult(statistic=-67.72699832580281, pvalue=1.0)]
#  [92.0
#   Ttest_1sampResult(statistic=1.0259725417825973, pvalue=0.16257113204445872)]
#  [93.0
#   Ttest_1sampResult(statistic=5.208332059348908, pvalue=1.611003448253604e-07)]
#  [94.0
#   Ttest_1sampResult(statistic=8.095716365754889, pvalue=2.86928262088311e-15)]
#  [95.0
#   Ttest_1sampResult(statistic=-8.377468662297748, pvalue=0.9999999999999997)]
#  [96.0
#   Ttest_1sampResult(statistic=-6.810543125517749, pvalue=0.9999999999847777)]
#  [97.0 Ttest_1sampResult(statistic=-274.4857118099518, pvalue=1.0)]
#  [98.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [104.0 Ttest_1sampResult(statistic=-inf, pvalue=1.0)]
#  [105.0
#   Ttest_1sampResult(statistic=-25.503234515998862, pvalue=0.9992330283598921)]
#  [107.0
#   Ttest_1sampResult(statistic=-81.34927921159903, pvalue=0.9999244622298884)]
#  [108.0
#   Ttest_1sampResult(statistic=-26.764353401002346, pvalue=0.9999999996567227)]
#  [109.0
#   Ttest_1sampResult(statistic=-11.505844139530122, pvalue=0.9992953075179123)]
#  [110.0
#   Ttest_1sampResult(statistic=-11.785237036402732, pvalue=0.9730553368782542)]
#  [111.0
#   Ttest_1sampResult(statistic=-48.74428305112485, pvalue=0.9997896955023254)]
#  [112.0
#   Ttest_1sampResult(statistic=-56.65611287953228, pvalue=0.9999939436136964)]
#  [113.0
#   Ttest_1sampResult(statistic=-36.23420139871812, pvalue=0.999999999977005)]
#  [114.0
#   Ttest_1sampResult(statistic=-1.8646398160476787, pvalue=0.9615122285261433)]
#  [115.0
#   Ttest_1sampResult(statistic=-0.3235797744940772, pvalue=0.6242986633867107)]
#  [116.0
#   Ttest_1sampResult(statistic=0.7917631224157892, pvalue=0.23640245497512521)]
#  [117.0
#   Ttest_1sampResult(statistic=2.351621787911368, pvalue=0.07151424745469875)]
#  [118.0
#   Ttest_1sampResult(statistic=-11.416459062790329, pvalue=0.972189316002571)]
#  [120.0 Ttest_1sampResult(statistic=-18.501920723462707, pvalue=1.0)]
#  [121.0 Ttest_1sampResult(statistic=-17.348040099234467, pvalue=1.0)]
#  [122.0 Ttest_1sampResult(statistic=-22.42603305659343, pvalue=1.0)]
#  [123.0
#   Ttest_1sampResult(statistic=0.5243341203172921, pvalue=0.30385408514114054)]
#  [124.0
#   Ttest_1sampResult(statistic=-8.722513688344568, pvalue=0.999999911260219)]
#  [125.0
#   Ttest_1sampResult(statistic=-6.154956589809591, pvalue=0.9999947083164954)]
#  [126.0 Ttest_1sampResult(statistic=-26.33547051120831, pvalue=1.0)]
#  [127.0
#   Ttest_1sampResult(statistic=-5.652802147304989, pvalue=0.9999998238731319)]
#  [128.0
#   Ttest_1sampResult(statistic=-9.193292318161145, pvalue=0.9999999999999966)]
#  [129.0 Ttest_1sampResult(statistic=-83.62272597755602, pvalue=1.0)]
#  [131.0
#   Ttest_1sampResult(statistic=-2.3230583224163985, pvalue=0.9756567845870326)]
#  [132.0
#   Ttest_1sampResult(statistic=-1.2012307492710346, pvalue=0.8810184725710194)]
#  [133.0
#   Ttest_1sampResult(statistic=6.456303526883811, pvalue=1.8423837844132655e-09)]
#  [134.0
#   Ttest_1sampResult(statistic=15.141178401142644, pvalue=1.5699045438399891e-32)]
#  [135.0
#   Ttest_1sampResult(statistic=14.738692606751426, pvalue=3.9395913096796326e-31)]
#  [136.0
#   Ttest_1sampResult(statistic=8.205026199779315, pvalue=8.077776275365187e-14)]
#  [137.0 Ttest_1sampResult(statistic=-20.776920543099216, pvalue=1.0)]
#  [138.0 Ttest_1sampResult(statistic=-15.42193610309063, pvalue=1.0)]
#  [139.0
#   Ttest_1sampResult(statistic=-10.856643872975154, pvalue=0.9999999999999997)]
#  [140.0
#   Ttest_1sampResult(statistic=-0.0593738902036394, pvalue=0.5236077485979477)]
#  [141.0
#   Ttest_1sampResult(statistic=6.051973625006832, pvalue=1.3800820142869844e-08)]
#  [142.0 Ttest_1sampResult(statistic=-30.744093906676948, pvalue=1.0)]
#  [143.0 Ttest_1sampResult(statistic=-16.726634242560383, pvalue=1.0)]
#  [144.0 Ttest_1sampResult(statistic=-21.54451777116237, pvalue=1.0)]
#  [145.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]]

# %%
x = stu_ttest_per_chn(split_1)
#np.save('/Users/carlosaguila/PycharmProjects/CNT_Interictal_Spikes/Results_v1/t_test_output_20rand_1.npy',x)
print(x)
# Out:
# [[7.0
#   Ttest_1sampResult(statistic=7.066050014413505, pvalue=5.848174479772292e-09)]
#  [8.0
#   Ttest_1sampResult(statistic=3.1200748438530854, pvalue=0.001450242328980792)]
#  [9.0
#   Ttest_1sampResult(statistic=2.77032572996267, pvalue=0.00399737516494066)]
#  [10.0
#   Ttest_1sampResult(statistic=5.584720216501055, pvalue=2.5018838243913257e-06)]
#  [11.0
#   Ttest_1sampResult(statistic=0.8618048420863447, pvalue=0.19673375510688784)]
#  [12.0
#   Ttest_1sampResult(statistic=-2.684690432056391, pvalue=0.9946508864412192)]
#  [13.0
#   Ttest_1sampResult(statistic=-2.2708124967894117, pvalue=0.9795964520710745)]
#  [14.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [15.0
#   Ttest_1sampResult(statistic=-17.313577878390866, pvalue=0.9999999999984419)]
#  [16.0 Ttest_1sampResult(statistic=-20.704147808181123, pvalue=1.0)]
#  [17.0 Ttest_1sampResult(statistic=-29.818954792744492, pvalue=1.0)]
#  [18.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [20.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [22.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [26.0
#   Ttest_1sampResult(statistic=4.017919730805846, pvalue=0.02836222249172877)]
#  [27.0
#   Ttest_1sampResult(statistic=4.522873839329966, pvalue=0.0004339666310041846)]
#  [28.0
#   Ttest_1sampResult(statistic=2.541020173374032, pvalue=0.008438970215736433)]
#  [29.0 Ttest_1sampResult(statistic=-29.027060561579233, pvalue=1.0)]
#  [30.0
#   Ttest_1sampResult(statistic=-14.839236481786385, pvalue=0.9999999999999666)]
#  [31.0
#   Ttest_1sampResult(statistic=-13.635995930492808, pvalue=0.9999999999983546)]
#  [32.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [34.0
#   Ttest_1sampResult(statistic=-0.4325091889253388, pvalue=0.6665639550207559)]
#  [35.0
#   Ttest_1sampResult(statistic=-1.8913609813897942, pvalue=0.9685819043664007)]
#  [36.0
#   Ttest_1sampResult(statistic=6.496880080693464, pvalue=5.528941528017731e-10)]
#  [37.0 Ttest_1sampResult(statistic=-12.460537305579043, pvalue=1.0)]
#  [38.0
#   Ttest_1sampResult(statistic=2.9784800868608783, pvalue=0.001747840588049224)]
#  [39.0
#   Ttest_1sampResult(statistic=0.04670761265000403, pvalue=0.48140594370345763)]
#  [40.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [41.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [42.0 Ttest_1sampResult(statistic=-20.349892914515507, pvalue=1.0)]
#  [43.0 Ttest_1sampResult(statistic=-19.414443713662532, pvalue=1.0)]
#  [44.0 Ttest_1sampResult(statistic=-18.425298014449307, pvalue=1.0)]
#  [45.0
#   Ttest_1sampResult(statistic=7.64033259743769, pvalue=9.492709409111224e-12)]
#  [46.0
#   Ttest_1sampResult(statistic=14.058105879382731, pvalue=2.738179382517534e-29)]
#  [47.0
#   Ttest_1sampResult(statistic=7.355621626037448, pvalue=9.947010399073308e-11)]
#  [48.0
#   Ttest_1sampResult(statistic=5.330019193795794, pvalue=1.223023084437201e-07)]
#  [49.0
#   Ttest_1sampResult(statistic=31.075721992482485, pvalue=4.353431968953848e-96)]
#  [50.0
#   Ttest_1sampResult(statistic=19.972513459115902, pvalue=2.8378661966460993e-64)]
#  [51.0
#   Ttest_1sampResult(statistic=6.78557415012926, pvalue=1.5849314154110896e-11)]
#  [52.0 Ttest_1sampResult(statistic=-33.19961961193752, pvalue=1.0)]
#  [53.0
#   Ttest_1sampResult(statistic=-8.206294446499147, pvalue=0.9999999999999905)]
#  [54.0 Ttest_1sampResult(statistic=-21.671587014428614, pvalue=1.0)]
#  [55.0 Ttest_1sampResult(statistic=-17.109576127548927, pvalue=1.0)]
#  [56.0 Ttest_1sampResult(statistic=-14.939031997638809, pvalue=1.0)]
#  [57.0
#   Ttest_1sampResult(statistic=16.503518081086593, pvalue=1.1445663184174057e-35)]
#  [58.0
#   Ttest_1sampResult(statistic=2.362769157953172, pvalue=0.009588548230505345)]
#  [59.0
#   Ttest_1sampResult(statistic=-7.154311194867374, pvalue=0.9999999999316246)]
#  [60.0
#   Ttest_1sampResult(statistic=-7.120855410616876, pvalue=0.9999999996476905)]
#  [61.0
#   Ttest_1sampResult(statistic=-7.319501873344196, pvalue=0.9999999999384236)]
#  [62.0
#   Ttest_1sampResult(statistic=-9.217631069983852, pvalue=0.9999999999998819)]
#  [63.0
#   Ttest_1sampResult(statistic=-9.6743004824381, pvalue=0.9999999972475944)]
#  [65.0
#   Ttest_1sampResult(statistic=-0.1498638749308386, pvalue=0.5587307615820019)]
#  [66.0
#   Ttest_1sampResult(statistic=-4.503604141698053, pvalue=0.999993728690497)]
#  [67.0
#   Ttest_1sampResult(statistic=-4.899203664900522, pvalue=0.9999988592736635)]
#  [68.0 Ttest_1sampResult(statistic=-9.361081394733716, pvalue=1.0)]
#  [69.0 Ttest_1sampResult(statistic=-11.359166185876575, pvalue=1.0)]
#  [70.0
#   Ttest_1sampResult(statistic=-0.10207884277776377, pvalue=0.540531310468453)]
#  [71.0
#   Ttest_1sampResult(statistic=-6.951211840348563, pvalue=0.999999999710132)]
#  [72.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [73.0 Ttest_1sampResult(statistic=-56.45615344847632, pvalue=1.0)]
#  [74.0
#   Ttest_1sampResult(statistic=-10.856381122973847, pvalue=0.9999999832745375)]
#  [75.0
#   Ttest_1sampResult(statistic=2.9520366137155785, pvalue=0.0028873582194539273)]
#  [76.0
#   Ttest_1sampResult(statistic=-0.3716658224763273, pvalue=0.6445320203003571)]
#  [77.0
#   Ttest_1sampResult(statistic=-0.31372754106626094, pvalue=0.6226412963267254)]
#  [78.0
#   Ttest_1sampResult(statistic=5.75971721806093, pvalue=8.745442459544487e-08)]
#  [79.0 Ttest_1sampResult(statistic=-31.89544153243807, pvalue=1.0)]
#  [80.0 Ttest_1sampResult(statistic=-21.703209286925183, pvalue=1.0)]
#  [81.0 Ttest_1sampResult(statistic=-128.17338692876925, pvalue=1.0)]
#  [83.0
#   Ttest_1sampResult(statistic=-27.78517988479112, pvalue=0.9999488342142803)]
#  [84.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [85.0
#   Ttest_1sampResult(statistic=4.768684722214492, pvalue=0.0001834478345916175)]
#  [86.0
#   Ttest_1sampResult(statistic=2.803052935276322, pvalue=0.003419837249374064)]
#  [87.0
#   Ttest_1sampResult(statistic=7.145135695492762, pvalue=1.368061978417735e-10)]
#  [88.0
#   Ttest_1sampResult(statistic=-3.9182910704441434, pvalue=0.9999368466146888)]
#  [89.0 Ttest_1sampResult(statistic=-19.999706547203697, pvalue=1.0)]
#  [90.0
#   Ttest_1sampResult(statistic=7.157069184169613, pvalue=1.7067179749059455e-11)]
#  [91.0 Ttest_1sampResult(statistic=-67.72248138049214, pvalue=1.0)]
#  [92.0
#   Ttest_1sampResult(statistic=1.0259883653555457, pvalue=0.16256755258991423)]
#  [93.0
#   Ttest_1sampResult(statistic=5.208037765059536, pvalue=1.6133794474144875e-07)]
#  [94.0
#   Ttest_1sampResult(statistic=8.093958321375863, pvalue=2.9055317896358434e-15)]
#  [95.0
#   Ttest_1sampResult(statistic=-8.376615334160192, pvalue=0.9999999999999997)]
#  [96.0
#   Ttest_1sampResult(statistic=-6.8125695357334655, pvalue=0.9999999999849714)]
#  [97.0 Ttest_1sampResult(statistic=-274.45917259346504, pvalue=1.0)]
#  [98.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]
#  [104.0 Ttest_1sampResult(statistic=-inf, pvalue=1.0)]
#  [105.0
#   Ttest_1sampResult(statistic=-25.497698048393595, pvalue=0.9992326960158552)]
#  [107.0
#   Ttest_1sampResult(statistic=-80.91481782068207, pvalue=0.9999236490583271)]
#  [108.0
#   Ttest_1sampResult(statistic=-26.79428622978557, pvalue=0.9999999996601201)]
#  [109.0
#   Ttest_1sampResult(statistic=-11.503919863403153, pvalue=0.9992949601146492)]
#  [110.0
#   Ttest_1sampResult(statistic=-11.758306641177724, pvalue=0.9729939201067401)]
#  [111.0
#   Ttest_1sampResult(statistic=-48.8151454925316, pvalue=0.9997903052518746)]
#  [112.0
#   Ttest_1sampResult(statistic=-56.52615256012993, pvalue=0.9999939017759907)]
#  [113.0
#   Ttest_1sampResult(statistic=-36.19846776588256, pvalue=0.9999999999768011)]
#  [114.0
#   Ttest_1sampResult(statistic=-1.8627601548209547, pvalue=0.961374401411236)]
#  [115.0
#   Ttest_1sampResult(statistic=-0.32150860401652515, pvalue=0.6235320958648012)]
#  [116.0
#   Ttest_1sampResult(statistic=0.7923360528609088, pvalue=0.23625319133765135)]
#  [117.0
#   Ttest_1sampResult(statistic=2.3515298557444355, pvalue=0.07151869666484462)]
#  [118.0
#   Ttest_1sampResult(statistic=-11.43730423259208, pvalue=0.9722397457835441)]
#  [120.0 Ttest_1sampResult(statistic=-18.5047328562953, pvalue=1.0)]
#  [121.0 Ttest_1sampResult(statistic=-17.348615443611948, pvalue=1.0)]
#  [122.0 Ttest_1sampResult(statistic=-22.423107079076168, pvalue=1.0)]
#  [123.0
#   Ttest_1sampResult(statistic=0.5243466296659725, pvalue=0.30384984082763594)]
#  [124.0
#   Ttest_1sampResult(statistic=-8.71545499460152, pvalue=0.9999999102945045)]
#  [125.0
#   Ttest_1sampResult(statistic=-6.154194266500167, pvalue=0.9999947004448555)]
#  [126.0 Ttest_1sampResult(statistic=-26.338069412179845, pvalue=1.0)]
#  [127.0
#   Ttest_1sampResult(statistic=-5.653036923040034, pvalue=0.9999998240358847)]
#  [128.0
#   Ttest_1sampResult(statistic=-9.193451338300966, pvalue=0.9999999999999966)]
#  [129.0 Ttest_1sampResult(statistic=-83.65760781086317, pvalue=1.0)]
#  [131.0
#   Ttest_1sampResult(statistic=-2.32279547207553, pvalue=0.9756467937934241)]
#  [132.0
#   Ttest_1sampResult(statistic=-1.200633780385927, pvalue=0.8809042031682179)]
#  [133.0
#   Ttest_1sampResult(statistic=6.457662826177721, pvalue=1.8306835764582915e-09)]
#  [134.0
#   Ttest_1sampResult(statistic=15.141945522106315, pvalue=1.5625919830056703e-32)]
#  [135.0
#   Ttest_1sampResult(statistic=14.737824026502846, pvalue=3.960173996246832e-31)]
#  [136.0
#   Ttest_1sampResult(statistic=8.20483456640393, pvalue=8.086376403290931e-14)]
#  [137.0 Ttest_1sampResult(statistic=-20.780662758184835, pvalue=1.0)]
#  [138.0 Ttest_1sampResult(statistic=-15.42507284224706, pvalue=1.0)]
#  [139.0
#   Ttest_1sampResult(statistic=-10.860581052723488, pvalue=0.9999999999999997)]
#  [140.0
#   Ttest_1sampResult(statistic=-0.058884502973334314, pvalue=0.5234133907552084)]
#  [141.0
#   Ttest_1sampResult(statistic=6.051145172142772, pvalue=1.3852277389157224e-08)]
#  [142.0 Ttest_1sampResult(statistic=-30.745478107761574, pvalue=1.0)]
#  [143.0 Ttest_1sampResult(statistic=-16.723065694947657, pvalue=1.0)]
#  [144.0 Ttest_1sampResult(statistic=-21.54654997712346, pvalue=1.0)]
#  [145.0 Ttest_1sampResult(statistic=nan, pvalue=nan)]]

# %% [markdown]
# Channels with <0.05 p value = 141,133-136, 93-94, 90, 87, 78, 57, 45-51, 36, 10, 7
#
# pvalues are calculated to have a mean max per channel greater than our representative mean max per channel.
#
#
#
# Want to look at normalizing these features for the amplitude thing
# look at SOZ vs NONSOZ channels vs features.
# maybe reduce the amount of "values" i store and just pull more for each sequence.
#
# next steps:
# baseline the signal
# find absolute maxes - make sure that the math works out.
# ranked sum tests?
# try to sperate into 2 groups - SOZ channels and non SOZ channels, find single feature to represent and then compare.
